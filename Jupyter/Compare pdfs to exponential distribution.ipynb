# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('/gymreklab-tscc/cynthiawu/Test_nullsnps/simulate_eqtls_only/FastMultivariate/Single_eqtl/SampleSize100/SingleParameter/numTarget_1000/Beta_01/Simulation_0/CPMA/gene-snp-eqtl', sep='\t')

# %%
data
# Out:
#         SNP       gene      beta    t-stat   p-value       FDR
# 0      SNP0   Gene1944 -0.639958 -5.075810  0.000002  0.027534
# 1      SNP0   Gene9369  0.564295  4.656741  0.000010  0.075768
# 2      SNP0   Gene8458  0.481575  4.019763  0.000114  0.572357
# 3      SNP0   Gene9229 -0.498894 -3.872809  0.000194  0.728459
# 4      SNP0    Gene183  0.460146  3.696518  0.000360  0.817147
# ...     ...        ...       ...       ...       ...       ...
# 14995  SNP0   Gene8315 -0.000024 -0.000170  0.999865  0.999927
# 14996  SNP0  Gene12533  0.000019  0.000136  0.999891  0.999927
# 14997  SNP0  Gene12139  0.000016  0.000115  0.999908  0.999927
# 14998  SNP0   Gene5855 -0.000017 -0.000115  0.999909  0.999927
# 14999  SNP0  Gene12475 -0.000011 -0.000092  0.999927  0.999927
#
# [15000 rows x 6 columns]

# %%
import scipy.stats
import seaborn as sns

# %%
def plot_exp(param):
    x = np.linspace(0, 10, 5000)
    y = scipy.stats.expon.pdf(x, scale=1/param)
    plt.plot(x, y)

# %%
plt.figure(figsize=[15, 10])
pvalues = -np.log(list(data['p-value']))
max_lklh = 1 / np.mean(pvalues)
sns.distplot(pvalues, bins=300, kde=True)
plot_exp(param=max_lklh)
plot_exp(param=1)
plt.xlim((0, 10))
plt.legend([f'pdf_{max_lklh:0.5}', f'pdf_1', 'hist'])
plt.title('Comparing distribution of -log(pvalues) for #target=1000 and beta=0.1 to exponential distribution with max_likelihood=1 and max_likelihood observed from data')

pass

# %%
# ?scipy.exp

# %%
data001 = pd.read_csv('/gymreklab-tscc/cynthiawu/Test_nullsnps/simulate_eqtls_only/FastMultivariate/Single_eqtl/SampleSize100/SingleParameter/numTarget_1000/Beta_001/Simulation_0/CPMA/gene-snp-eqtl', sep='\t')

# %%
plt.figure(figsize=[15, 10])
pvalues = -np.log(list(data001['p-value']))
max_lklh = 1 / np.mean(pvalues)
sns.distplot(pvalues, kde=True)
plot_exp(param=max_lklh)
plot_exp(param=1)
plt.xlim((0, 10))
plt.legend([f'pdf_{max_lklh:0.5}', f'pdf_1', 'hist'])
plt.title('Comparing distribution of -log(pvalues) for #target=1000 and beta=0.01 to exponential distribution with max_likelihood=1 and max_likelihood observed from data')

pass

# %%
data0 = pd.read_csv('/gymreklab-tscc/cynthiawu/Test_nullsnps/simulate_eqtls_only/FastMultivariate/Single_eqtl/SampleSize100/SingleParameter/numTarget_0/Beta_001/Simulation_0/CPMA/gene-snp-eqtl', sep='\t')

# %%
plt.figure(figsize=[15, 10])
pvalues = -np.log(list(data0['p-value']))
max_lklh = 1 / np.mean(pvalues)
sns.distplot(pvalues, kde=True)
plot_exp(param=max_lklh)
plot_exp(param=1)
plt.xlim((0, 10))
plt.legend([f'pdf_{max_lklh:0.5}', f'pdf_1', 'hist'])
pass

# %%
data_pc1000 = pd.read_csv('/gymreklab-tscc/cynthiawu/Test_nullsnps/simulate_eqtls_only/FastMultivariate/Single_eqtl/SampleSize100/SingleParameter/numTarget_1000/Beta_1/Simulation_0/expressionPCs/gene-snp-eqtl_PCs', sep='\t')
plt.figure(figsize=[15, 10])
pvalues = -np.log(list(data_pc1000['p-value']))
max_lklh = 1 / np.mean(pvalues)
sns.distplot(pvalues, kde=True)
plot_exp(param=max_lklh)
plot_exp(param=1)
plt.xlim((0, 10))
plt.legend([f'pdf_{max_lklh:0.5}', f'pdf_1', 'hist'])
plt.title('Comparing distribution of -log(pvalues) for #target=1000 and beta=1 to exponential distribution with max_likelihood=1 and max_likelihood observed from data')
pass
