# %%
import pandas as pd
import sklearn.decomposition
import matplotlib.pyplot as plt

# %% [markdown]
# ## Simulated dataset with gene-gene correlation

# %%
expression = pd.read_csv('/gymreklab-tscc/cynthiawu/real_gene_correlation/SampleSize500/numTarget_100/Beta_01/Simulation_0/expression.csv', sep='\t')
expression.set_index('Unnamed: 0', inplace=True)

# %%
expression
# Out:
#              Sample0   Sample1   Sample2   Sample3   Sample4   Sample5  \
# Unnamed: 0
# Gene0       0.227193  0.271714 -0.918499  0.603131 -0.772169  1.427272
# Gene1      -0.048498 -0.996031  2.266342  0.656362  0.039576 -0.794025
# Gene2       0.755927  0.186462 -1.660561  0.610190 -0.538363  0.770348
# Gene3       0.131703  0.319997  1.577153  1.500098 -0.015124  0.396599
# Gene4      -0.404962  0.434856  2.287254  0.076605  1.336286 -0.340243
# ...              ...       ...       ...       ...       ...       ...
# Gene14995   0.230243  0.208583  1.149078  0.533222  0.660541 -0.922446
# Gene14996  -0.082576 -0.197257 -0.180773 -0.515906  0.324688 -0.436053
# Gene14997  -0.081424  0.732670 -0.392950  1.581452  0.817483  1.098981
# Gene14998   0.927032 -0.776001 -1.889613 -0.653484 -1.280644 -0.245929
# Gene14999  -1.146606 -1.578095  1.948561  0.195304 -0.186799  0.157409
#
#              Sample6   Sample7   Sample8   Sample9  ...  Sample490  Sample491  \
# ...

# %%
pca = sklearn.decomposition.PCA()
pca.fit(expression)
expression_pca = pca.transform(expression)

# %%
pca.explained_variance_
# Out:
# array([6.12408328e+01, 4.35467428e+01, 3.54807263e+01, 2.98453206e+01,
#        2.54884527e+01, 2.08382388e+01, 1.75330870e+01, 1.62436931e+01,
#        1.52994298e+01, 1.09121657e+01, 1.00631260e+01, 8.09966512e+00,
#        7.79055940e+00, 7.45756183e+00, 6.68448563e+00, 5.83887450e+00,
#        5.35302949e+00, 4.67304290e+00, 4.38113502e+00, 4.29331805e+00,
#        4.04513546e+00, 3.82854344e+00, 3.48987885e+00, 3.33233647e+00,
#        3.20995430e+00, 3.04382058e+00, 2.89999793e+00, 2.86104664e+00,
#        2.74150999e+00, 2.63669504e+00, 2.48667032e+00, 2.46607493e+00,
#        2.36586624e+00, 2.28888764e+00, 2.22666341e+00, 2.16856957e+00,
#        2.12135943e+00, 2.01898899e+00, 1.91594395e+00, 1.90010362e+00,
#        1.83447416e+00, 1.77912939e+00, 1.76780949e+00, 1.72285999e+00,
#        1.70145143e+00, 1.66313133e+00, 1.61662530e+00, 1.57752004e+00,
#        1.54267401e+00, 1.52199225e+00, 1.49478543e+00, 1.43616688e+00,
# ...

# %%
plt.hist(pca.explained_variance_)
# Out:
# (array([485.,   6.,   3.,   1.,   2.,   1.,   0.,   1.,   0.,   1.]),
#  array([1.72223781e-05, 6.12409878e+00, 1.22481803e+01, 1.83722619e+01,
#         2.44963434e+01, 3.06204250e+01, 3.67445066e+01, 4.28685881e+01,
#         4.89926697e+01, 5.51167512e+01, 6.12408328e+01]),
#  <a list of 10 Patch objects>)

# %%
PC_df = pd.DataFrame(expression_pca)

# %%
PC_df
# Out:
#              0          1         2          3          4         5    \
# 0      -8.486303   6.639334  2.339148  12.185308  -0.784585 -5.922204
# 1       2.827434   2.197197  4.759985  -4.788108   5.410387  0.435674
# 2       8.555095  10.546065 -9.917749   5.666210  -2.561250 -4.186516
# 3      -9.896493   2.178537 -3.298499  -5.766678  -1.869223  2.823338
# 4     -11.576832  -0.505051 -1.031572  -8.925960  -4.052335  3.865380
# ...          ...        ...       ...        ...        ...       ...
# 14995   0.943564   1.374234 -6.608181  -8.394478   0.303272  6.450955
# 14996  -6.812785  -2.594721 -0.495765   5.958754  -1.576250 -0.231785
# 14997   8.494264   3.720271  3.732599   5.713423  10.160726  7.915279
# 14998   3.963306  -5.570587 -7.205560  13.504518  -1.765541 -4.903251
# 14999  -1.017174  -0.876370 -2.830500  -3.486924   6.578000 -0.394352
#
#             6         7         8         9    ...       490       491  \
# ...

# %%
len(expression_trans_pca[0])
# Out:
# 100

# %%
len(samples)
# Out:
# 500

# %%
input = '/gymreklab-tscc/cynthiawu/real_gene_correlation/SampleSize500/numTarget_100/Beta_01/Simulation_0/expression.csv'
expression = pd.read_csv(input, sep='\t')
expression.set_index('Unnamed: 0', inplace=True)
samples = list(expression.columns)
expression_trans = expression.values.transpose()
pca = sklearn.decomposition.PCA(n_components=100)
pca.fit(expression_trans)
expression_trans_pca = pca.transform(expression_trans)
PCs = ['PC' + str(i) for i in range(len(expression_trans_pca[0]))]
PC_trans_df = pd.DataFrame(expression_trans_pca.T, columns=samples, index=PCs)
# PC_trans_df.to_csv(output, sep='\t')

# %%
PC_trans_df
# Out:
#         Sample0    Sample1     Sample2    Sample3    Sample4    Sample5  \
# PC0   53.557724  21.392746  -52.153652 -25.419667 -14.234181  -4.445019
# PC1   21.933351  26.480758  -61.859728  92.837488  51.543006  43.136605
# PC2   48.316131 -17.355772  -23.884659   1.570075   6.113429   7.836046
# PC3  -16.076861  -2.328593  108.677799  56.148860  45.884993  -2.337551
# PC4  -26.048591   7.435148   -6.450275  34.911070  -9.737741  38.954912
# ...         ...        ...         ...        ...        ...        ...
# PC95  -3.318975  -0.427790    6.316814  -1.227513  -6.854492   6.565096
# PC96   4.003174   4.846505    0.300523  -2.746199  -9.479160   3.913932
# PC97   3.451203  -5.702192    1.568976  -7.941107  -4.756124   1.827704
# PC98   6.351446  -0.131083    5.378513  -3.206741  -5.530941  -4.509873
# PC99  -6.083002   3.802155    0.907203  -2.389419   5.031683  -3.748103
#
#         Sample6    Sample7    Sample8    Sample9  ...  Sample490  Sample491  \
# ...

# %%
pca.explained_variance_
# Out:
# array([1.88786635e+03, 1.31014252e+03, 1.07198223e+03, 9.80794560e+02,
#        7.64809312e+02, 6.48287274e+02, 5.74698912e+02, 5.13167225e+02,
#        4.62190578e+02, 3.30359033e+02, 3.11723290e+02, 2.40757564e+02,
#        2.38274748e+02, 2.24330481e+02, 2.01019893e+02, 1.75503765e+02,
#        1.65370418e+02, 1.40630750e+02, 1.31041395e+02, 1.29265773e+02,
#        1.22781117e+02, 1.16109981e+02, 1.06218856e+02, 1.03513733e+02,
#        9.76516547e+01, 9.13003112e+01, 8.70302928e+01, 8.65707061e+01,
#        8.26489928e+01, 7.91531838e+01, 7.52878957e+01, 7.43949064e+01,
#        7.13160511e+01, 6.87401859e+01, 6.70894900e+01, 6.50173080e+01,
#        6.37697313e+01, 6.11889429e+01, 5.79790681e+01, 5.68890198e+01,
#        5.47582979e+01, 5.34138452e+01, 5.30122640e+01, 5.20585509e+01,
#        5.14915927e+01, 5.00448208e+01, 4.87021491e+01, 4.74757621e+01,
#        4.69748104e+01, 4.59313975e+01, 4.50341476e+01, 4.34024278e+01,
# ...

# %%
plt.hist(pca.explained_variance_)
plt.title('Histogram of eigenvalues of PCs for gene-gene correlation')
plt.xlabel('Eigenvalues')
# Out:
# Text(0.5, 0, 'Eigenvalues')

# %%
plt.hist(pca.explained_variance_)
plt.xscale("log")

# %%
PC_trans_df
# Out:
#             Sample0       Sample1       Sample2       Sample3       Sample4  \
# PC0    5.355772e+01  2.139275e+01 -5.215365e+01 -2.541967e+01 -1.423418e+01
# PC1    2.193335e+01  2.648076e+01 -6.185973e+01  9.283749e+01  5.154301e+01
# PC2    4.831613e+01 -1.735577e+01 -2.388466e+01  1.570075e+00  6.113429e+00
# PC3   -1.607686e+01 -2.328593e+00  1.086778e+02  5.614886e+01  4.588499e+01
# PC4   -2.604859e+01  7.435148e+00 -6.450275e+00  3.491107e+01 -9.737741e+00
# ...             ...           ...           ...           ...           ...
# PC495 -4.849463e-03 -3.700811e-02  2.546169e-03  4.084509e-03 -6.785767e-03
# PC496 -2.062101e-02  1.845036e-02 -1.174205e-02 -5.522949e-03  9.602736e-03
# PC497  2.888523e-02 -1.367676e-02  2.095453e-02  3.544347e-02 -1.580950e-03
# PC498 -2.082878e-03  1.449533e-02 -1.421001e-02  1.153473e-02 -8.462599e-03
# PC499 -2.910866e-15  3.951700e-15  8.715251e-15  1.567496e-14  8.944234e-15
#
# ...

# %%
input = '/gymreklab-tscc/cynthiawu/Test_nullsnps/simulate_eqtls_only/FastMultivariate/Single_eqtl/SampleSize500/SingleParameter/numTarget_100/Beta_01/Simulation_0/expression.csv'
expression = pd.read_csv(input, sep='\t')
expression.set_index('Unnamed: 0', inplace=True)
samples = list(expression.columns)
expression_trans = expression.values.transpose()
pca = sklearn.decomposition.PCA()
pca.fit(expression_trans)
expression_trans_pca = pca.transform(expression_trans)
PCs = ['PC' + str(i) for i in range(len(expression_trans_pca))]
PC_trans_df = pd.DataFrame(expression_trans_pca.T, columns=samples, index=PCs)
# PC_trans_df.to_csv(output, sep='\t')

# %%
plt.hist(pca.explained_variance_)
plt.title('Histogram of eigenvalues of PCs for cov=identity')
plt.xlabel('Eigenvalues')
# Out:
# Text(0.5, 0, 'Eigenvalues')

# %%
plt.hist(pca.explained_variance_)
plt.xscale("log")

# %%
PC_trans_df
# Out:
#             Sample0       Sample1       Sample2       Sample3       Sample4  \
# PC0   -8.772475e-01  2.044992e+00 -6.553442e-01  1.941150e+00 -5.320291e-02
# PC1    4.589071e+00 -4.564216e+00  3.053992e+00  2.041430e-01 -7.268925e+00
# PC2    5.613442e+00  5.604647e+00 -7.628100e+00  4.209296e+00 -1.051634e+00
# PC3    6.075475e+00  3.290744e+00 -2.996740e+00  9.404015e-01  1.039159e+01
# PC4   -2.957515e+00 -1.454047e+01  5.922208e+00  6.910675e+00  4.141383e+00
# ...             ...           ...           ...           ...           ...
# PC495 -1.439898e+00  8.623122e-01 -6.102678e+00  7.250165e+00 -1.309938e-01
# PC496 -3.653703e+00 -5.759808e+00  9.802278e-01 -7.095437e+00  3.942135e+00
# PC497 -3.291920e+00 -3.102084e+00  1.574924e-01  9.300303e-01  3.502239e+00
# PC498  4.977393e-01 -1.213362e+00  2.682316e+00  4.901054e-01  4.073270e+00
# PC499  4.690692e-15 -3.330669e-16  1.547373e-15  7.341350e-15  5.245804e-15
#
# ...

# %% [markdown]
# ### Checking cpma power

# %%
file = '/gymreklab-tscc/cynthiawu/real_gene_correlation/SampleSize500/numTarget_1000/Beta_0/Simulation_0/expressionPCs/gene-snp-eqtl_PCs_cpmax_pvalues_1.0'
cpma_file = pd.read_csv(file, sep='\t')

# %%
float(cpma_file.loc[cpma_file['snp'] == 'SNP0']['pvalue'])
# Out:
# 0.964137455628818

# %% [markdown]
# ## Previous attempt with simulated dataset with cov=identity

# %%
expression = pd.read_csv('/gymreklab-tscc/cynthiawu/Test_nullsnps/simulate_eqtls_only/FastMultivariate/Single_eqtl/SampleSize500/SingleParameter/numTarget_100/Beta_01/Simulation_0/expression.csv', sep='\t')
expression.set_index('Unnamed: 0', inplace=True)

# %%
expression
# Out:
#              Sample0   Sample1   Sample2   Sample3   Sample4   Sample5  \
# Unnamed: 0
# Gene0      -0.001697  1.325945  0.874192  0.012158  0.376174 -0.807098
# Gene1       0.119279  0.224767  0.755175  0.774830 -1.460627 -1.448190
# Gene2       1.949591 -1.701820  2.588384  0.699063 -1.475923  1.636282
# Gene3      -0.114167  0.522852  0.263757 -0.774100  1.761390  0.801585
# Gene4      -0.399017 -0.183034 -0.100628  0.468956  1.210328  0.769424
# ...              ...       ...       ...       ...       ...       ...
# Gene14995  -0.610009  0.130848  0.330265  1.392616 -0.338875 -0.159819
# Gene14996  -0.098225 -0.887191  0.683399 -0.551925 -1.018836 -0.473317
# Gene14997   1.424325 -1.155371 -0.105057 -0.648764  0.538356  0.306777
# Gene14998  -1.546722 -0.809948  1.336198  0.607317  0.294494 -0.455094
# Gene14999  -0.399342  0.939834 -0.874302 -0.411441 -0.492447  0.492842
#
#              Sample6   Sample7   Sample8   Sample9  ...  Sample490  Sample491  \
# ...

# %%
samples = list(expression.columns)

# %%
pca = sklearn.decomposition.PCA()
pca.fit(expression)
expression_pca = pca.transform(expression)

# %%
plt.hist(pca.explained_variance_)
# Out:
# (array([39., 59., 65., 64., 63., 59., 53., 44., 36., 18.]),
#  array([0.67079498, 0.74367171, 0.81654844, 0.88942517, 0.96230189,
#         1.03517862, 1.10805535, 1.18093208, 1.25380881, 1.32668554,
#         1.39956227]),
#  <a list of 10 Patch objects>)

# %%
expression.shape
# Out:
# (15000, 100)

# %%
expression_pca.shape
# Out:
# (15000, 100)

# %%
len(expression_pca[0,:])
# Out:
# 100

# %%
expression_pca
# Out:
# array([[12.65428285, -0.83761113, -0.07019144, ..., -0.57040621,
#         -0.98301246,  0.21462127],
#        [10.53300381,  0.1950959 ,  0.25905141, ...,  0.37685026,
#          0.43347371, -1.70749972],
#        [11.3837511 ,  2.1764016 ,  0.16349646, ..., -1.5631775 ,
#          0.83121924, -1.66500216],
#        ...,
#        [-1.28597236, -1.68139124, -1.40762861, ..., -0.57494415,
#          0.67691364, -1.02334111],
#        [-1.35438236,  0.68270725,  0.07612342, ..., -1.31989998,
#          0.04727589,  1.56469231],
#        [-2.09208107, -0.82848272,  0.53199765, ...,  1.07277274,
#         -0.50068055,  0.12846392]])

# %%
PC_df = pd.DataFrame(expression_pca)

# %%
col = ['Sample' + str(i) for i in range(len(expression_pca))]

# %%
col
# Out:
# ['Sample0',
#  'Sample1',
#  'Sample2',
#  'Sample3',
#  'Sample4',
#  'Sample5',
#  'Sample6',
#  'Sample7',
#  'Sample8',
#  'Sample9',
#  'Sample10',
#  'Sample11',
#  'Sample12',
#  'Sample13',
#  'Sample14',
#  'Sample15',
#  'Sample16',
#  'Sample17',
#  'Sample18',
#  'Sample19',
#  'Sample20',
#  'Sample21',
#  'Sample22',
#  'Sample23',
#  'Sample24',
#  'Sample25',
#  'Sample26',
#  'Sample27',
#  'Sample28',
#  'Sample29',
#  'Sample30',
#  'Sample31',
#  'Sample32',
#  'Sample33',
#  'Sample34',
#  'Sample35',
#  'Sample36',
#  'Sample37',
#  'Sample38',
#  'Sample39',
#  'Sample40',
#  'Sample41',
#  'Sample42',
#  'Sample43',
#  'Sample44',
#  'Sample45',
#  'Sample46',
#  'Sample47',
#  'Sample48',
#  'Sample49',
#  'Sample50',
#  'Sample51',
#  'Sample52',
#  'Sample53',
#  'Sample54',
#  'Sample55',
#  'Sample56',
#  'Sample57',
#  'Sample58',
#  'Sample59',
#  'Sample60',
#  'Sample61',
#  'Sample62',
#  'Sample63',
#  'Sample64',
#  'Sample65',
#  'Sample66',
# ...

# %%
PC_df
# Out:
#               0         1         2         3         4         5         6   \
# 0      12.654283 -0.837611 -0.070191  0.653667  0.313885 -0.890936  1.864463
# 1      10.533004  0.195096  0.259051  0.126535  0.344784 -1.259951  0.742675
# 2      11.383751  2.176402  0.163496 -1.197586 -1.541796  0.541826  0.849376
# 3      10.865595 -0.303197  0.438831 -1.059321  0.270942 -2.140000  0.930980
# 4      11.865518  0.888621  0.265698  1.886548  0.322141  1.670631  0.269225
# ...          ...       ...       ...       ...       ...       ...       ...
# 14995  -1.832272  0.680687 -0.469134  2.832163  0.542232 -0.485772 -0.401232
# 14996  -1.003284  0.121397  0.263009  1.203034 -2.520427  0.150159 -1.609258
# 14997  -1.285972 -1.681391 -1.407629 -0.672103 -1.482872  0.378250  0.161500
# 14998  -1.354382  0.682707  0.076123 -0.070289  1.534066 -0.082914  0.110850
# 14999  -2.092081 -0.828483  0.531998  1.087121  0.657787 -0.154021  0.615734
#
# ...

# %%
pca.n_samples_
# Out:
# 15000

# %%
pca.n_features_
# Out:
# 100

# %%
pca.explained_variance_
# Out:
# array([11.35365037,  1.15810064,  1.15587683,  1.14603993,  1.14300173,
#         1.13564505,  1.13456778,  1.1321766 ,  1.12023426,  1.11817786,
#         1.11625948,  1.11336399,  1.10655192,  1.10486306,  1.09877042,
#         1.09437493,  1.09039666,  1.08934434,  1.08507923,  1.08225812,
#         1.08125766,  1.07871322,  1.07546709,  1.07214855,  1.07009763,
#         1.06432073,  1.06053058,  1.05652778,  1.05575879,  1.05294284,
#         1.04937769,  1.04803629,  1.04455013,  1.04272866,  1.03971429,
#         1.03738137,  1.03561274,  1.03321907,  1.03012413,  1.0268237 ,
#         1.02434057,  1.02237778,  1.02004122,  1.01535908,  1.0126448 ,
#         1.01252522,  1.00723857,  1.00484107,  1.00268615,  1.00028176,
#         0.99582521,  0.9926808 ,  0.98970045,  0.98771285,  0.98595746,
#         0.98182608,  0.9790185 ,  0.97617401,  0.97325113,  0.97165858,
#         0.97098378,  0.96725075,  0.96306367,  0.95873226,  0.95746123,
# ...

# %%
expression_trans = expression.values.transpose()

# %%
pca = sklearn.decomposition.PCA(n_components=100, svd_solver='full')
pca.fit(expression.T)
expression_trans_pca = pca.transform(expression.T)

# %%
pca.n_samples_
# Out:
# 100

# %%
pca.n_features_
# Out:
# 15000

# %%
pd.DataFrame(expression_trans_pca.T, columns=samples)
# Out:
#          Sample0       Sample1       Sample2       Sample3       Sample4  \
# 0  -3.228325e+01 -8.025434e-02 -3.242974e+01 -3.358219e+01  3.885263e+01
# 1  -1.422643e+00 -2.140580e+00  4.710105e+00 -3.483599e+00  3.649575e+00
# 2  -4.859695e+00  3.298429e-01 -3.375526e+00  1.237550e+01  1.557662e+01
# 3   5.613004e+00  1.502864e+01 -8.633074e+00 -5.271728e+00 -1.611220e-01
# 4  -1.932334e+01 -1.464893e+01  1.174034e+01 -1.617403e+01  1.574630e+01
# ..           ...           ...           ...           ...           ...
# 95  1.869892e+01 -7.109543e+00 -3.034290e+00 -5.819638e+00  2.824493e+01
# 96 -6.097519e+00  1.218837e+01  1.817619e+01 -9.030394e+00 -3.805379e+00
# 97  1.963797e+00 -2.747179e+01  6.990647e+00  5.978199e+00  1.286080e+01
# 98 -2.176616e+01 -1.194747e+01  1.383996e+01 -1.714262e+01  1.125384e+01
# 99  1.953993e-14  1.609823e-14 -2.997602e-14 -4.435341e-14  3.708145e-14
#
#          Sample5       Sample6       Sample7       Sample8       Sample9  ...  \
# ...

# %%
PC_trans_df = pd.DataFrame(expression_trans_pca, index=samples)
PC_trans_df
# Out:
#                  0          1          2          3          4          5   \
# Sample0  -32.283252  -1.422643  -4.859695   5.613004 -19.323345 -14.542563
# Sample1   -0.080254  -2.140580   0.329843  15.028642 -14.648927  11.652627
# Sample2  -32.429735   4.710105  -3.375526  -8.633074  11.740345 -20.837513
# Sample3  -33.582193  -3.483599  12.375495  -5.271728 -16.174027   4.707649
# Sample4   38.852625   3.649575  15.576621  -0.161122  15.746302   4.974635
# ...             ...        ...        ...        ...        ...        ...
# Sample95  36.629901  -0.729192 -21.505033  -7.798767  15.992183   2.100933
# Sample96   3.702022  -4.772091   3.507981   2.903952  -0.746892   4.035335
# Sample97  37.620903 -13.976533  -4.822001  20.647330  25.494837  -1.666378
# Sample98   1.911333  -6.636585   0.100678  -3.853422 -22.092034  -0.577554
# Sample99  35.923803   5.709859  -1.582349 -17.134564   2.738309   8.015286
#
# ...

# %%
expression_trans_pca
# Out:
# array([[-3.22832521e+01, -1.42264283e+00, -4.85969511e+00, ...,
#          1.96379680e+00, -2.17661576e+01,  1.95399252e-14],
#        [-8.02543402e-02, -2.14058039e+00,  3.29842887e-01, ...,
#         -2.74717941e+01, -1.19474653e+01,  1.60982339e-14],
#        [-3.24297352e+01,  4.71010535e+00, -3.37552561e+00, ...,
#          6.99064737e+00,  1.38399572e+01, -2.99760217e-14],
#        ...,
#        [ 3.76209032e+01, -1.39765331e+01, -4.82200052e+00, ...,
#         -6.51249585e+00,  4.17835773e+00, -1.03805853e-14],
#        [ 1.91133331e+00, -6.63658524e+00,  1.00678414e-01, ...,
#         -9.52598845e+00, -5.16343106e+00,  1.39888101e-14],
#        [ 3.59238034e+01,  5.70985872e+00, -1.58234896e+00, ...,
#          4.97448023e+00,  6.42683496e-01,  1.99840144e-15]])

# %%
pca.explained_variance_
# Out:
# array([6.89998195e+02, 1.75434840e+02, 1.74075242e+02, 1.73610036e+02,
#        1.73149767e+02, 1.72044862e+02, 1.71868521e+02, 1.71515563e+02,
#        1.69417873e+02, 1.69127555e+02, 1.69019733e+02, 1.68272957e+02,
#        1.67608812e+02, 1.67395085e+02, 1.66444188e+02, 1.65405173e+02,
#        1.65073061e+02, 1.64963142e+02, 1.64407145e+02, 1.63951663e+02,
#        1.63688560e+02, 1.63347093e+02, 1.62774852e+02, 1.62385825e+02,
#        1.61296106e+02, 1.60974606e+02, 1.60484954e+02, 1.60079181e+02,
#        1.59748553e+02, 1.59537908e+02, 1.58963940e+02, 1.58422647e+02,
#        1.58229140e+02, 1.57598768e+02, 1.57180608e+02, 1.56970334e+02,
#        1.56593349e+02, 1.56135161e+02, 1.55578240e+02, 1.55270491e+02,
#        1.55154147e+02, 1.54859086e+02, 1.54545971e+02, 1.53798673e+02,
#        1.53421187e+02, 1.53204494e+02, 1.52535462e+02, 1.51930161e+02,
#        1.51705969e+02, 1.50884727e+02, 1.50563275e+02, 1.50181774e+02,
# ...

# %%
expression_trans_pca.shape
# Out:
# (100, 100)

# %%
len(expression_trans_pca[:,0])
# Out:
# 100

# %%
expression.shape
# Out:
# (15000, 100)

# %%
expression_trans.shape
# Out:
# (100, 15000)
