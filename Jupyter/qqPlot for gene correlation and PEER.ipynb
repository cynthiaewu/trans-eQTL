# %%
import pandas as pd
import numpy as np
import statsmodels.stats.multitest
import matplotlib.pyplot as plt
from scipy import stats
import statsmodels.api as sm

# %%
data = pd.read_csv('/gymreklab-tscc/cynthiawu/PEER_sim/SampleSize500/1000nullsnps/numTarget_1000/Beta_0/Simulation_1/CPMAx_PEER/gene-snp-eqtl_cpmax_pvalues_1.0', sep='\t')

# %%
pvals_peer = np.array(data['pvalue'])
# pvals_adj = statsmodels.stats.multitest.multipletests(pvals, alpha=0.25, method='holm')

# %%
# ?sm.qqplot

# %%
fig = plt.figure(figsize=(8, 6))
# ax = fig.add_subplot(111)
# rng = np.random.default_rng()
# x = stats.chi2.rvs(1, size=len(pvals), random_state=rng)

# ax.plot(x, rv.pdf(x), 'k-', lw=2, label='frozen pdf')
sm.qqplot(pvals_peer, dist='uniform', line='45')

pass

# %%
data = pd.read_csv('/gymreklab-tscc/cynthiawu/PEER_sim/SampleSize500/1000nullsnps/numTarget_1000/Beta_0/Simulation_0/CPMAx/gene-snp-eqtl_cpmax_pvalues_1.0', sep='\t')

# %%
pvals_nopeer = np.array(data['pvalue'])
fig = plt.figure(figsize=(8, 6))
ax = fig.add_subplot(111)
stats.probplot(pvals_nopeer, dist='uniform', plot=ax)

pass

# %%
plt.hist(pvals_peer)
# Out:
# (array([193., 114., 106.,  85.,  94.,  96.,  85.,  67.,  73.,  87.]),
#  array([2.74102830e-05, 9.97966536e-02, 1.99565897e-01, 2.99335140e-01,
#         3.99104384e-01, 4.98873627e-01, 5.98642870e-01, 6.98412114e-01,
#         7.98181357e-01, 8.97950601e-01, 9.97719844e-01]),
#  <a list of 10 Patch objects>)

# %%
(th_peer, emp_peer), _ = stats.probplot(pvals_peer, dist='uniform', plot=ax)
(th_nopeer, emp_nopeer), _ = stats.probplot(pvals_nopeer, dist='uniform', plot=ax)

# %%
plt.scatter(th_peer, emp_peer)
plt.scatter(th_peer, emp_nopeer)
plt.scatter(th_peer, th_peer)

# %%
fig = plt.figure(figsize=(8, 6))
ax = fig.add_subplot(111)

stats.probplot(pvals_peer, dist='uniform', plot=ax)

stats.probplot(pvals_nopeer, dist='uniform', plot=ax)
plt.show()
pass

# %%
data = pd.read_csv('/gymreklab-tscc/cynthiawu/PEER_sim/SampleSize500/1000nullsnps/numTarget_1000/Beta_0/Simulation_0/CPMA/gene-snp-eqtl_cpma_converted_chipvalues', sep='\t')
pvals_nopeer = np.array(data['pvalue'])
fig = plt.figure(figsize=(8, 6))
ax = fig.add_subplot(111)
stats.probplot(pvals_nopeer, dist='uniform', plot=ax)

pass

# %%
data = pd.read_csv('/gymreklab-tscc/cynthiawu/PEER_sim/SampleSize500/1000nullsnps/numTarget_1000/Beta_0/Simulation_0/CPMA_PEER/gene-snp-eqtl_cpma_converted_chipvalues', sep='\t')
pvals_peer = np.array(data['pvalue'])
fig = plt.figure(figsize=(8, 6))
ax = fig.add_subplot(111)
stats.probplot(pvals_peer, dist='uniform', plot=ax)

pass

# %%
plt.hist(pvals_peer)
# Out:
# (array([193., 143.,  96.,  96.,  95.,  87.,  62.,  84.,  61.,  83.]),
#  array([9.97338868e-05, 1.00021502e-01, 1.99943271e-01, 2.99865039e-01,
#         3.99786808e-01, 4.99708576e-01, 5.99630345e-01, 6.99552113e-01,
#         7.99473881e-01, 8.99395650e-01, 9.99317418e-01]),
#  <a list of 10 Patch objects>)

# %%
data = pd.read_csv('/gymreklab-tscc/cynthiawu/PEER_sim/SampleSize500/1000nullsnps/numTarget_1000/Beta_0/Simulation_0/CPMAx_PEER/gene-snp-eqtl_cpmax_pvalues_1.0', sep='\t')
pvals_peer = np.array(data['pvalue'])
fig = plt.figure(figsize=(8, 6))
ax = fig.add_subplot(111)
stats.probplot(pvals_peer, dist='uniform', plot=ax)

pass

# %%
plt.hist(pvals_peer)
# Out:
# (array([180., 119., 119.,  88.,  78.,  90.,  83.,  75.,  87.,  81.]),
#  array([7.15612570e-05, 1.00058430e-01, 2.00045299e-01, 3.00032168e-01,
#         4.00019037e-01, 5.00005906e-01, 5.99992775e-01, 6.99979644e-01,
#         7.99966513e-01, 8.99953381e-01, 9.99940250e-01]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# # Simulated PEER, corrected

# %%
data = pd.read_csv('/gymreklab-tscc/cynthiawu/PEER_sim/SampleSize500/1000nullsnps/numTarget_1000/Beta_0/Simulation_0/CPMA_PEER/gene-snp-eqtl_cpma_converted_chipvalues', sep='\t')
pvals_peer = np.array(data['pvalue'])

# %%
plt.hist(pvals_peer, bins=30)
# Out:
# (array([103.,  51.,  39.,  44.,  58.,  41.,  28.,  39.,  29.,  28.,  36.,
#          32.,  28.,  36.,  31.,  27.,  31.,  29.,  24.,  18.,  20.,  27.,
#          30.,  27.,  20.,  24.,  17.,  38.,  24.,  21.]),
#  array([9.97338868e-05, 3.34069900e-02, 6.67142462e-02, 1.00021502e-01,
#         1.33328758e-01, 1.66636015e-01, 1.99943271e-01, 2.33250527e-01,
#         2.66557783e-01, 2.99865039e-01, 3.33172295e-01, 3.66479552e-01,
#         3.99786808e-01, 4.33094064e-01, 4.66401320e-01, 4.99708576e-01,
#         5.33015832e-01, 5.66323088e-01, 5.99630345e-01, 6.32937601e-01,
#         6.66244857e-01, 6.99552113e-01, 7.32859369e-01, 7.66166625e-01,
#         7.99473881e-01, 8.32781138e-01, 8.66088394e-01, 8.99395650e-01,
#         9.32702906e-01, 9.66010162e-01, 9.99317418e-01]),
#  <a list of 30 Patch objects>)

# %%
fig = plt.figure(figsize=(8, 6))
sm.qqplot(pvals_peer, dist='uniform', line='45')

# %% [markdown]
# # Simulated PEER, uncorrected

# %%
data = pd.read_csv('/gymreklab-tscc/cynthiawu/PEER_sim/SampleSize500/1000nullsnps/numTarget_1000/Beta_0/Simulation_0/CPMA/gene-snp-eqtl_cpma_converted_chipvalues', sep='\t')
pvals_nopeer = np.array(data['pvalue'])

# %%
plt.hist(pvals_nopeer, bins=30)
# Out:
# (array([967.,   6.,   4.,   2.,   3.,   2.,   1.,   2.,   0.,   1.,   2.,
#           0.,   2.,   1.,   0.,   1.,   0.,   0.,   0.,   0.,   0.,   1.,
#           1.,   0.,   2.,   0.,   1.,   0.,   0.,   1.]),
#  array([0.        , 0.03079157, 0.06158314, 0.09237471, 0.12316628,
#         0.15395785, 0.18474941, 0.21554098, 0.24633255, 0.27712412,
#         0.30791569, 0.33870726, 0.36949883, 0.4002904 , 0.43108197,
#         0.46187354, 0.49266511, 0.52345667, 0.55424824, 0.58503981,
#         0.61583138, 0.64662295, 0.67741452, 0.70820609, 0.73899766,
#         0.76978923, 0.8005808 , 0.83137237, 0.86216394, 0.8929555 ,
#         0.92374707]),
#  <a list of 30 Patch objects>)

# %%
fig = plt.figure(figsize=(8, 6))
sm.qqplot(pvals_nopeer, dist='uniform', line='45')

# %%
# fig, ax1 = plt.subplots(1, 1, figsize=(6, 4))
fig = plt.figure(figsize=(12, 12), dpi=150)
ax1 = fig.add_subplot(111)
plt.yticks(fontsize=16)
plt.xticks(fontsize=8)
sm.qqplot(pvals_peer, dist='uniform', line='45', ax=ax1, label='adjusted')
sm.qqplot(pvals_nopeer, dist='uniform', line='45', ax=ax1, color='green', label='unadjusted')
plt.xlabel('Theoretical Quantiles', fontsize=18)
plt.ylabel('Sample Quantiles', fontsize=18)
plt.title('Adjusted vs unadjusted for PEER', fontsize=20)
lgnd = plt.legend(loc='upper left', scatterpoints=1, prop={'size': 18})
plt.savefig('/storage/cynthiawu/trans_eQTL/Scripts/Figures/PEER_qqplot.pdf', dpi=300, bbox_inches = "tight")

# %%
data
# Out:
#       snp        cpma    pvalue
# 0    SNP0  842.429186  0.285049
# 1    SNP1  101.816755  0.712219
# 2   SNP10  143.772433  0.661359
# 3   SNP11  384.361965  0.471743
# 4   SNP12    0.001461  0.998924
# ..    ...         ...       ...
# 95  SNP95  120.555436  0.688225
# 96  SNP96  940.509122  0.258091
# 97  SNP97  543.259223  0.391749
# 98  SNP98   99.283399  0.715715
# 99  SNP99   44.735246  0.806896
#
# [100 rows x 3 columns]

# %% [markdown]
# # Simulated gene correlation, corrected

# %%
pvals = []
for i in range(0, 6):
    data = pd.read_csv(f'/gymreklab-tscc/cynthiawu/real_gene_correlation/SampleSize500/firstTargets/numTarget_1000/Beta_0/Simulation_{i}/CPMA/gene-snp-eqtl_empiricalpvalues_topx_1.0_converted', sep='\t')
    pvals.append(np.array(data['pvalue']))
pvals_gene_corr = np.array(pvals).flatten()

# %%
plt.hist(pvals_gene_corr, bins=30)
# Out:
# (array([14., 13., 18., 16., 10., 22., 13., 21., 24., 20., 27., 23., 19.,
#         25., 17., 13., 23., 21., 17., 23., 22., 22., 26., 19., 26., 16.,
#         19., 18., 26., 27.]),
#  array([0.00310999, 0.03630379, 0.06949759, 0.10269139, 0.13588519,
#         0.169079  , 0.2022728 , 0.2354666 , 0.2686604 , 0.3018542 ,
#         0.335048  , 0.3682418 , 0.4014356 , 0.4346294 , 0.4678232 ,
#         0.501017  , 0.5342108 , 0.5674046 , 0.6005984 , 0.6337922 ,
#         0.666986  , 0.7001798 , 0.7333736 , 0.7665674 , 0.7997612 ,
#         0.832955  , 0.8661488 , 0.8993426 , 0.9325364 , 0.9657302 ,
#         0.998924  ]),
#  <a list of 30 Patch objects>)

# %%
fig = plt.figure(figsize=(8, 6))
ax = fig.add_subplot(111)
stats.probplot(pvals_gene_corr, dist='uniform', plot=ax)

pass

# %%
import scipy
scipy.stats.kstest(pvals_gene_corr, 'uniform')
# Out:
# KstestResult(statistic=0.06069085861828277, pvalue=0.023066043934711785)

# %%
fig = plt.figure(figsize=(8, 6))
sm.qqplot(pvals_gene_corr, dist='uniform', line='45')

# %% [markdown]
# # Simulated gene correlation, not corrected

# %%
pvals = []
for i in range(0, 6):
    data = pd.read_csv(f'/gymreklab-tscc/cynthiawu/real_gene_correlation/SampleSize500/firstTargets/numTarget_1000/Beta_0/Simulation_{i}/CPMAx/gene-snp-eqtl_cpma_topx_1.0_converted_chisquare', sep='\t')
    pvals.append(np.array(data['pvalue']))
pvals_gene_nocorr = np.array(pvals).flatten()

# %%
plt.hist(pvals_gene_nocorr, bins=30)
# Out:
# (array([552.,   4.,   6.,   2.,   1.,   1.,   6.,   1.,   2.,   1.,   0.,
#           4.,   0.,   3.,   1.,   2.,   1.,   1.,   0.,   1.,   2.,   1.,
#           2.,   0.,   1.,   0.,   1.,   2.,   0.,   2.]),
#  array([0.        , 0.03231713, 0.06463427, 0.0969514 , 0.12926853,
#         0.16158567, 0.1939028 , 0.22621993, 0.25853707, 0.2908542 ,
#         0.32317133, 0.35548847, 0.3878056 , 0.42012273, 0.45243987,
#         0.484757  , 0.51707413, 0.54939127, 0.5817084 , 0.61402553,
#         0.64634267, 0.6786598 , 0.71097693, 0.74329406, 0.7756112 ,
#         0.80792833, 0.84024546, 0.8725626 , 0.90487973, 0.93719686,
#         0.969514  ]),
#  <a list of 30 Patch objects>)

# %%
fig = plt.figure(figsize=(8, 6))
ax = fig.add_subplot(111)
stats.probplot(pvals_gene_nocorr, dist='uniform', plot=ax)

pass

# %%
sm.qqplot(pvals_gene_nocorr, dist='uniform', line='45')

# %%
# ?sm.qqplot

# %%
# fig, ax1 = plt.subplots(1, 1, figsize=(6, 4))
fig = plt.figure(figsize=(12, 12), dpi=150)
ax1 = fig.add_subplot(111)
plt.yticks(fontsize=16)
plt.xticks(fontsize=8)
sm.qqplot(pvals_gene_corr, dist='uniform', line='45', ax=ax1, label='adjusted')
sm.qqplot(pvals_gene_nocorr, dist='uniform', line='45', ax=ax1, color='green', label='unadjusted')
plt.xlabel('Theoretical Quantiles', fontsize=18)
plt.ylabel('Sample Quantiles', fontsize=18)
plt.title('Adjusted vs unadjusted for gene correlation', fontsize=20)
lgnd = plt.legend(loc='upper left', scatterpoints=1, prop={'size': 18})
plt.savefig('/storage/cynthiawu/trans_eQTL/Scripts/Figures/gene_correlation_qqplot.pdf', dpi=300, bbox_inches = "tight")

# %%
def QQPlot(pvals1, pvals2, pvals3, pvals4):
    # Sort the observed p-values
    pvals1.sort()
    pvals2.sort()
    pvals3.sort()
    pvals4.sort()
    # Generate some random data from uniform distribution 
    unif1 = list(np.random.uniform(0, 1, size=len(pvals1))) 
    unif1.sort()
    unif2 = list(np.random.uniform(0, 1, size=len(pvals3))) 
    unif2.sort()
    # Make a QQ plot
    fig = plt.figure(figsize=(12, 12), dpi=150)
    ax = fig.add_subplot(111)
    ax.scatter(-1*np.log10(unif1), -1*np.log10(pvals1), s=20, color="lightcoral", label='adjusted, gene correlation') 
    ax.scatter(-1*np.log10(unif1), -1*np.log10(pvals2), s=20, color="maroon", label='unadjusted, gene correlation') 
    ax.scatter(-1*np.log10(unif2), -1*np.log10(pvals3), s=20, color="skyblue", label='adjusted, PEER') 
    ax.scatter(-1*np.log10(unif2), -1*np.log10(pvals4), s=20, color="blue", label='unadjusted, PEER') 

    ax.set_xlim(-0.05, 3.05)
    ax.set_ylim(-0.05, 3.05)
    ax.plot([-0.05, 3.05], [-0.05, 3.05], color="black")
    lgnd = plt.legend(loc='lower right', scatterpoints=1, prop={'size': 18})
    lgnd.legendHandles[0]._sizes = [200]
    lgnd.legendHandles[1]._sizes = [200]
    lgnd.legendHandles[2]._sizes = [200]
    lgnd.legendHandles[3]._sizes = [200]

#     ax.set_xlim(left=0, right=3)
#     ax.set_ylim(bottom=0, top=max(-1*np.log10([item for item in pvals if item>0])))
    ax.set_xlabel("Expected -log10(P)") 
    ax.set_ylabel("Observed -log10(P)")

# %%
plt.rcParams['pdf.fonttype'] = 42
plt.rcParams['ps.fonttype'] = 42
QQPlot(pvals_gene_corr, pvals_gene_nocorr, pvals_peer, pvals_nopeer)
plt.title('Adjusted vs unadjusted for gene correlation or PEER', fontsize=20)
plt.savefig('/storage/cynthiawu/trans_eQTL/Scripts/Figures/gene_correlation_PEER_neglog_qqplot.pdf', dpi=300, bbox_inches = "tight")
# Out:
# /storage/cynthiawu/miniconda3/envs/python3.6/lib/python3.6/site-packages/ipykernel_launcher.py:16: RuntimeWarning: divide by zero encountered in log10
#   app.launch_new_instance()
# /storage/cynthiawu/miniconda3/envs/python3.6/lib/python3.6/site-packages/ipykernel_launcher.py:18: RuntimeWarning: divide by zero encountered in log10

# %%
plt.rcParams['pdf.fonttype'] = 42
plt.rcParams['ps.fonttype'] = 42
QQPlot(pvals_gene_corr, pvals_gene_nocorr, pvals_peer, pvals_nopeer)
plt.title('Adjusted vs unadjusted for gene correlation or PEER', fontsize=20)
plt.savefig('/storage/cynthiawu/trans_eQTL/Scripts/Figures/gene_correlation_PEER_neglog_qqplot_largedots.pdf', dpi=300, bbox_inches = "tight")
# Out:
# /storage/cynthiawu/miniconda3/envs/python3.6/lib/python3.6/site-packages/ipykernel_launcher.py:16: RuntimeWarning: divide by zero encountered in log10
#   app.launch_new_instance()
# /storage/cynthiawu/miniconda3/envs/python3.6/lib/python3.6/site-packages/ipykernel_launcher.py:18: RuntimeWarning: divide by zero encountered in log10

# %%
plt.rcParams['pdf.fonttype'] = 42
plt.rcParams['ps.fonttype'] = 42
QQPlot(pvals_gene_corr, pvals_gene_nocorr, pvals_peer, pvals_nopeer)
plt.title('Adjusted vs unadjusted for gene correlation or PEER', fontsize=20)
plt.savefig('/storage/cynthiawu/trans_eQTL/Scripts/Figures/gene_correlation_PEER_neglog_qqplot_largedots_maroon.pdf', dpi=300, bbox_inches = "tight")
# Out:
# /storage/cynthiawu/miniconda3/envs/python3.6/lib/python3.6/site-packages/ipykernel_launcher.py:16: RuntimeWarning: divide by zero encountered in log10
#   app.launch_new_instance()
# /storage/cynthiawu/miniconda3/envs/python3.6/lib/python3.6/site-packages/ipykernel_launcher.py:18: RuntimeWarning: divide by zero encountered in log10

# %%
QQPlot(pvals_gene_corr, pvals_gene_nocorr)
plt.title('Adjusted vs unadjusted for gene correlation', fontsize=20)
plt.savefig('/storage/cynthiawu/trans_eQTL/Scripts/Figures/gene_correlation_neglog_qqplot.pdf', dpi=300, bbox_inches = "tight")
# Out:
# /storage/cynthiawu/miniconda3/envs/python3.6/lib/python3.6/site-packages/ipykernel_launcher.py:12: RuntimeWarning: divide by zero encountered in log10
#   if sys.path[0] == '':

# %%
QQPlot(pvals_peer, pvals_nopeer)
plt.title('Adjusted vs unadjusted for PEER', fontsize=20)
plt.savefig('/storage/cynthiawu/trans_eQTL/Scripts/Figures/PEER_neglog_qqplot.pdf', dpi=300, bbox_inches = "tight")
# Out:
# /storage/cynthiawu/miniconda3/envs/python3.6/lib/python3.6/site-packages/ipykernel_launcher.py:12: RuntimeWarning: divide by zero encountered in log10
#   if sys.path[0] == '':

# %%
len(pvals_gene_corr)
# Out:
# 600

# %%
len(pvals_gene_nocorr)
# Out:
# 600

# %%
plt.rcParams['pdf.fonttype'] = 42
plt.rcParams['ps.fonttype'] = 42
QQPlot(pvals_gene_corr, pvals_gene_nocorr, pvals_peer, pvals_nopeer)
plt.title('Adjusted vs unadjusted for gene correlation or PEER', fontsize=20)
# plt.savefig('/storage/cynthiawu/trans_eQTL/Scripts/Figures/gene_correlation_PEER_neglog_qqplot_largedots_maroon.pdf', dpi=300, bbox_inches = "tight")
# Out:
# /storage/cynthiawu/miniconda3/envs/python3.6/lib/python3.6/site-packages/ipykernel_launcher.py:16: RuntimeWarning: divide by zero encountered in log10
#   app.launch_new_instance()
# /storage/cynthiawu/miniconda3/envs/python3.6/lib/python3.6/site-packages/ipykernel_launcher.py:18: RuntimeWarning: divide by zero encountered in log10
# Text(0.5, 1.0, 'Adjusted vs unadjusted for gene correlation or PEER')

# %% [markdown]
# # Add baseline null pvals to QQplot

# %%
def QQPlot_null(pvals0, pvals1, pvals2, pvals3, pvals4):
    # Sort the observed p-values
    pvals0.sort()
    pvals1.sort()
    pvals2.sort()
    pvals3.sort()
    pvals4.sort()
    # Generate some random data from uniform distribution 
    unif0 = list(np.random.uniform(0, 1, size=len(pvals0))) 
    unif0.sort()
    unif1 = list(np.random.uniform(0, 1, size=len(pvals1))) 
    unif1.sort()
    unif2 = list(np.random.uniform(0, 1, size=len(pvals3))) 
    unif2.sort()
    # Make a QQ plot
    fig = plt.figure(figsize=(12, 12), dpi=150)
    ax = fig.add_subplot(111)
    ax.scatter(-1*np.log10(unif0), -1*np.log10(pvals0), s=20, color="purple", label='baseline') 
    ax.scatter(-1*np.log10(unif1), -1*np.log10(pvals1), s=20, color="lightcoral", label='adjusted, gene correlation') 
    ax.scatter(-1*np.log10(unif1), -1*np.log10(pvals2), s=20, color="maroon", label='unadjusted, gene correlation') 
    ax.scatter(-1*np.log10(unif2), -1*np.log10(pvals3), s=20, color="skyblue", label='adjusted, PEER') 
    ax.scatter(-1*np.log10(unif2), -1*np.log10(pvals4), s=20, color="blue", label='unadjusted, PEER') 

    ax.set_xlim(-0.05, 3.05)
    ax.set_ylim(-0.05, 3.05)
    ax.plot([-0.05, 3.05], [-0.05, 3.05], color="black")
    lgnd = plt.legend(loc='lower right', scatterpoints=1, prop={'size': 18})
    lgnd.legendHandles[0]._sizes = [200]
    lgnd.legendHandles[1]._sizes = [200]
    lgnd.legendHandles[2]._sizes = [200]
    lgnd.legendHandles[3]._sizes = [200]
    lgnd.legendHandles[4]._sizes = [200]

#     ax.set_xlim(left=0, right=3)
#     ax.set_ylim(bottom=0, top=max(-1*np.log10([item for item in pvals if item>0])))
    ax.set_xlabel("Expected -log10(P)") 
    ax.set_ylabel("Observed -log10(P)")

# %%
baseline_null_results = pd.read_csv('/storage/cynthiawu/trans_eQTL/baseline_null/sim-0/baseline_null_results.tab', sep='\t')

# %%
baseline_null_results
# Out:
#           SNP      CPMA    CPMA_p      xQTL  predicted_T  predicted_L  \
# 0        SNP0  0.002893  0.957105  0.002911     0.500000     0.999116
# 1        SNP1  0.208751  0.647748  0.211959     0.499996     0.992434
# 2       SNP10  0.321423  0.570754  0.320102     0.499965     1.009235
# 3      SNP100  0.016499  0.897795  0.016396     0.500001     0.997916
# 4     SNP1000  0.545074  0.460338  0.558705     0.499924     1.012383
# ...       ...       ...       ...       ...          ...          ...
# 2995   SNP995  0.329304  0.566069  0.326042     0.499966     1.009294
# 2996   SNP996  1.250008  0.263551  1.283388     0.499824     1.018804
# 2997   SNP997  1.279314  0.258027  1.290152     0.499847     1.018688
# 2998   SNP998  0.983785  0.321266  0.985001     0.499890     1.016264
# 2999   SNP999  0.212147  0.645090  0.216021     0.499971     1.007669
#
#         xQTL_p
# 0     0.956974
# 1     0.645236
# 2     0.571546
# 3     0.898112
# 4     0.454782
# ...        ...
# ...

# %%
baseline_pvals = list(baseline_null_results['CPMA_p'])

# %%
/gymreklab-tscc/cynthiawu/Test_nullsnps/simulate_eqtls_only/FastMultivariate/Single_eqtl/SampleSize500/SingleParameter/numTarget_0/Beta_0/Simulation_1/CPMAx/gene-snp-eqtl_cpmax_pvalues_1.0

# %%
plt.rcParams['pdf.fonttype'] = 42
plt.rcParams['ps.fonttype'] = 42
QQPlot_null(baseline_pvals, pvals_gene_corr, pvals_gene_nocorr, pvals_peer, pvals_nopeer)
plt.title('Adjusted vs unadjusted for gene correlation or PEER', fontsize=20)
plt.savefig('/storage/cynthiawu/trans_eQTL/Figures/gene_correlation_PEER_neglog_qqplot_baseline.pdf', dpi=300, bbox_inches = "tight")
# Out:
# /storage/cynthiawu/miniconda3/envs/python3.6/lib/python3.6/site-packages/ipykernel_launcher.py:20: RuntimeWarning: divide by zero encountered in log10
# /storage/cynthiawu/miniconda3/envs/python3.6/lib/python3.6/site-packages/ipykernel_launcher.py:22: RuntimeWarning: divide by zero encountered in log10

# %%
scipy.stats.kstest(baseline_pvals, 'uniform')
# Out:
# KstestResult(statistic=0.02938707226075643, pvalue=0.01123801453173419)

# %%
len(pvals_gene_corr)
# Out:
# 600

# %%
import scipy.stats as stats

# %%
np.array(baseline_pvals).shape
# Out:
# (3000,)

# %%
plt.rcParams['pdf.fonttype'] = 42
plt.rcParams['ps.fonttype'] = 42
plt.figure(figsize=(12, 8), dpi=150)
fig = sm.qqplot(-1*np.log10(np.array(baseline_pvals)), (stats.expon), fit=True, line="45")
plt.show()

# %%
plt.rcParams['pdf.fonttype'] = 42
plt.rcParams['ps.fonttype'] = 42
plt.figure(figsize=(12, 8), dpi=150)
fig = sm.qqplot((np.array(pvals_gene_nocorr)), (stats.uniform), line="45")
plt.show()

# %%
import numpy as np
import pylab

test1 = -1*np.log10(baseline_pvals)
# test1 = np.random.normal(0, 1, 1000)
test2 = -1*np.log10(np.random.uniform(0, 1, size=10000))

#Calculate quantiles
test1.sort()
quantile_levels1 = np.arange(len(test1),dtype=float)/len(test1)

test2.sort()
quantile_levels2 = np.arange(len(test2),dtype=float)/len(test2)

#Use the smaller set of quantile levels to create the plot
quantile_levels = quantile_levels2

#We already have the set of quantiles for the smaller data set
quantiles2 = test2

#We find the set of quantiles for the larger data set using linear interpolation
quantiles1 = np.interp(quantile_levels,quantile_levels1,test1)

#Plot the quantiles to create the qq plot
pylab.plot(quantiles1,quantiles2)

#Add a reference line
maxval = max(test1[-1],test2[-1])
minval = min(test1[0],test2[0])
pylab.plot([minval,maxval],[minval,maxval],'k-')

pylab.show()

# %%
data = pd.read_csv('/gymreklab-tscc/cynthiawu/real_gene_correlation/SampleSize500/firstTargets/numTarget_1000/Beta_0/Simulation_0/CPMA/gene-snp-eqtl_empiricalpvalues_topx_1.0_converted', sep='\t')
pvals = np.array(data['pvalue'])
fig = plt.figure(figsize=(8, 6))
ax = fig.add_subplot(111)
stats.probplot(pvals, dist='uniform', plot=ax)

pass
