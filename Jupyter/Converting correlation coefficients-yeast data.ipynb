# %%
import pandas as pd
import numpy as np
from scipy import stats

# %%
corrcoef = pd.read_csv('/storage/cynthiawu/trans_eQTL/Scripts/yeast/yeast_corrcoeff.csv', sep=' ')

# %%
rows = corrcoef.index
columns = corrcoef.columns

# %%
corrcoef
# Out:
#          chrI:33040_A/G  chrI:33293_A/T  chrI:34170_T/A  chrI:34308_C/T  \
# YAL062W       -0.759388       -0.759712       -0.758224       -0.754258
# YAL061W       -0.030602       -0.030970       -0.027881       -0.026861
# YAL060W        0.535035        0.542822        0.544211        0.552621
# YAL059W        0.030814        0.035424        0.033950        0.037754
# YAL058W       -0.037349       -0.031714       -0.033086       -0.031602
# ...                 ...             ...             ...             ...
# YPR202W       -0.016559       -0.023314       -0.023856       -0.021564
# YPR203W       -0.008048       -0.013472       -0.013956       -0.017103
# YPR204W       -0.025495       -0.027071       -0.027370       -0.024072
# Q0130         -0.016685       -0.020517       -0.020425       -0.030432
# Q0140          0.031483        0.032816        0.029755        0.030075
#
#          chrI:34554_A/G  chrI:35128_AG/A  chrI:35466_G/A  chrI:35818_A/G  \
# ...

# %%
n = 1012
se = np.sqrt(n-3)

# %%
zscores = np.arctanh(corrcoef)*se

# %%
zscores
# Out:
#          chrI:33040_A/G  chrI:33293_A/T  chrI:34170_T/A  chrI:34308_C/T  \
# YAL062W       -0.994768       -0.995535       -0.992023       -0.982760
# YAL061W       -0.030612       -0.030980       -0.027889       -0.026867
# YAL060W        0.597173        0.608148        0.610119        0.622147
# YAL059W        0.030824        0.035439        0.033963        0.037772
# YAL058W       -0.037367       -0.031724       -0.033098       -0.031612
# ...                 ...             ...             ...             ...
# YPR202W       -0.016560       -0.023318       -0.023861       -0.021567
# YPR203W       -0.008048       -0.013473       -0.013957       -0.017104
# YPR204W       -0.025500       -0.027078       -0.027377       -0.024077
# Q0130         -0.016687       -0.020520       -0.020427       -0.030441
# Q0140          0.031494        0.032828        0.029764        0.030084
#
#          chrI:34554_A/G  chrI:35128_AG/A  chrI:35466_G/A  chrI:35818_A/G  \
# ...

# %%
zscores
# Out:
#          chrI:33040_A/G  chrI:33293_A/T  chrI:34170_T/A  chrI:34308_C/T  \
# YAL062W      -31.598579      -31.622916      -31.511386      -31.217146
# YAL061W       -0.972379       -0.984084       -0.885873       -0.853426
# YAL060W       18.969061       19.317666       19.380271       19.762337
# YAL059W        0.979111        1.125721        1.078838        1.199822
# YAL058W       -1.186941       -1.007720       -1.051350       -1.004158
# ...                 ...             ...             ...             ...
# YPR202W       -0.526027       -0.740686       -0.757939       -0.685074
# YPR203W       -0.255646       -0.427971       -0.443332       -0.543311
# YPR204W       -0.810013       -0.860122       -0.869619       -0.764805
# Q0130         -0.530052       -0.651815       -0.648872       -0.966962
# Q0140          1.000394        1.042772        0.945447        0.955611
#
#          chrI:34554_A/G  chrI:35128_AG/A  chrI:35466_G/A  chrI:35818_A/G  \
# ...

# %%
pvalues = 2*stats.norm.cdf(-np.abs(zscores))

# %%
pvals_df = pd.DataFrame(pvalues, index=rows, columns=columns)

# %%
pvals_df
# Out:
#          chrI:33040_A/G  chrI:33293_A/T  chrI:34170_T/A  chrI:34308_C/T  \
# YAL062W   3.861753e-219   1.787914e-219   6.065924e-218   6.235902e-214
# YAL061W    3.308622e-01    3.250741e-01    3.756859e-01    3.934231e-01
# YAL060W    3.073470e-80    3.815114e-83    1.132499e-83    6.282698e-87
# YAL059W    3.275253e-01    2.602835e-01    2.806601e-01    2.302083e-01
# YAL058W    2.352508e-01    3.135889e-01    2.930977e-01    3.153026e-01
# ...                 ...             ...             ...             ...
# YPR202W    5.988694e-01    4.588841e-01    4.484877e-01    4.932972e-01
# YPR203W    7.982242e-01    6.686725e-01    6.575256e-01    5.869156e-01
# YPR204W    4.179327e-01    3.897215e-01    3.845088e-01    4.443877e-01
# Q0130      5.960760e-01    5.145207e-01    5.164214e-01    3.335631e-01
# Q0140      3.171200e-01    2.970537e-01    3.444308e-01    3.392687e-01
#
#          chrI:34554_A/G  chrI:35128_AG/A  chrI:35466_G/A  chrI:35818_A/G  \
# ...

# %%
pvals_df.T
# Out:
#                          YAL062W   YAL061W       YAL060W   YAL059W   YAL058W  \
# chrI:33040_A/G     3.861753e-219  0.330862  3.073470e-80  0.327525  0.235251
# chrI:33293_A/T     1.787914e-219  0.325074  3.815114e-83  0.260283  0.313589
# chrI:34170_T/A     6.065924e-218  0.375686  1.132499e-83  0.280660  0.293098
# chrI:34308_C/T     6.235902e-214  0.393423  6.282698e-87  0.230208  0.315303
# chrI:34554_A/G     1.333376e-210  0.437913  8.280784e-91  0.279070  0.389865
# ...                          ...       ...           ...       ...       ...
# chrXVI:925172_C/G   6.034183e-02  0.097591  7.750564e-02  0.937079  0.607247
# chrXVI:925497_A/C   7.350047e-02  0.091195  7.486422e-02  0.984523  0.609677
# chrXVI:925746_T/A   6.055342e-02  0.129015  6.641264e-02  0.981876  0.632652
# chrXVI:927980_A/G   7.902179e-02  0.106589  5.371471e-02  0.880087  0.550014
# chrXVI:928107_C/T   5.332773e-02  0.152073  3.580483e-02  0.845749  0.655151
#
# ...

# %%
zscores.T
# Out:
#                      YAL062W   YAL061W    YAL060W   YAL059W   YAL058W  \
# chrI:33040_A/G    -31.598579 -0.972379  18.969061  0.979111 -1.186941
# chrI:33293_A/T    -31.622916 -0.984084  19.317666  1.125721 -1.007720
# chrI:34170_T/A    -31.511386 -0.885873  19.380271  1.078838 -1.051350
# chrI:34308_C/T    -31.217146 -0.853426  19.762337  1.199822 -1.004158
# chrI:34554_A/G    -30.970802 -0.775722  20.208265  1.082412 -0.859863
# ...                      ...       ...        ...       ...       ...
# chrXVI:925172_C/G  -1.878288  1.656646   1.765346  0.078942  0.514008
# chrXVI:925497_A/C  -1.789710  1.689125   1.781295  0.019399  0.510535
# chrXVI:925746_T/A  -1.876742  1.517999   1.835628 -0.022717  0.477998
# chrXVI:927980_A/G  -1.756390  1.613718   1.929130 -0.150859  0.597739
# chrXVI:928107_C/T  -1.932257  1.432247   2.099137 -0.194546  0.446618
#
#                      YAL056W   YAL055W    YAL054C   YAL053W   YAL051W  ...  \
# ...

# %%
pvals_df.T.to_csv('/storage/cynthiawu/trans_eQTL/Scripts/yeast/yeast_pvals.csv', sep='\t')

# %%
zscores.T.to_csv('/storage/cynthiawu/trans_eQTL/Scripts/yeast/yeast_zscores.csv', sep='\t')

# %%
np.arctanh(-0.99)
# Out:
# -2.6466524123622457

# %%
sum((zscores < -1).all())
# Out:
# 0

# %%
n = 1012
dist = stats.beta(n/2 - 1, n/2 - 1, loc=-1, scale=2)

# %%
dist

# %%
def r_to_pvalue(r):
    return 2*dist.cdf(-np.abs(r))

# %%
corrcoef
# Out:
#          chrI:33040_A/G  chrI:33293_A/T  chrI:34170_T/A  chrI:34308_C/T  \
# YAL062W       -0.759388       -0.759712       -0.758224       -0.754258
# YAL061W       -0.030602       -0.030970       -0.027881       -0.026861
# YAL060W        0.535035        0.542822        0.544211        0.552621
# YAL059W        0.030814        0.035424        0.033950        0.037754
# YAL058W       -0.037349       -0.031714       -0.033086       -0.031602
# ...                 ...             ...             ...             ...
# YPR202W       -0.016559       -0.023314       -0.023856       -0.021564
# YPR203W       -0.008048       -0.013472       -0.013956       -0.017103
# YPR204W       -0.025495       -0.027071       -0.027370       -0.024072
# Q0130         -0.016685       -0.020517       -0.020425       -0.030432
# Q0140          0.031483        0.032816        0.029755        0.030075
#
#          chrI:34554_A/G  chrI:35128_AG/A  chrI:35466_G/A  chrI:35818_A/G  \
# ...

# %%
rows = corrcoef.index
columns = corrcoef.columns

# %%
# corrcoef.applymap(r_to_pvalue)

# %%
pvals = r_to_pvalue(corrcoef)

# %%
pvals
# Out:
# array([[9.80731788e-191, 5.44637448e-191, 8.05111265e-190, ...,
#         6.05644573e-002, 7.90238274e-002, 5.33421098e-002],
#        [3.30780083e-001, 3.24992944e-001, 3.75598525e-001, ...,
#         1.28992687e-001, 1.06577111e-001, 1.52040882e-001],
#        [5.09566886e-076, 1.27820648e-078, 4.32146346e-079, ...,
#         6.64208699e-002, 5.37289131e-002, 3.58262518e-002],
#        ...,
#        [4.17842568e-001, 3.89633039e-001, 3.84420642e-001, ...,
#         3.05504960e-087, 1.05958243e-093, 1.49367550e-094],
#        [5.95993489e-001, 5.14431207e-001, 5.16332052e-001, ...,
#         7.14900394e-002, 6.32979368e-002, 8.42113529e-002],
#        [3.17040058e-001, 2.96977391e-001, 3.44346887e-001, ...,
#         5.01649852e-001, 4.55444863e-001, 5.34385863e-001]])

# %%
pvals.shape
# Out:
# (5720, 11530)

# %%
r_to_pvalue([-0.759388])
# Out:
# array([9.81166023e-191])

# %%
pvals_df = pd.DataFrame(pvals, index=rows, columns=columns)

# %%
pvals_df
# Out:
#          chrI:33040_A/G  chrI:33293_A/T  chrI:34170_T/A  chrI:34308_C/T  \
# YAL062W   9.807318e-191   5.446374e-191   8.051113e-190   9.568750e-187
# YAL061W    3.307801e-01    3.249929e-01    3.755985e-01    3.933344e-01
# YAL060W    5.095669e-76    1.278206e-78    4.321463e-79    5.439506e-82
# YAL059W    3.274438e-01    2.602152e-01    2.805871e-01    2.301482e-01
# YAL058W    2.351892e-01    3.135095e-01    2.930221e-01    3.152230e-01
# ...                 ...             ...             ...             ...
# YPR202W    5.987872e-01    4.587931e-01    4.483967e-01    4.932069e-01
# YPR203W    7.981764e-01    6.686000e-01    6.574514e-01    5.868320e-01
# YPR204W    4.178426e-01    3.896330e-01    3.844206e-01    4.442968e-01
# Q0130      5.959935e-01    5.144312e-01    5.163321e-01    3.334806e-01
# Q0140      3.170401e-01    2.969774e-01    3.443469e-01    3.391855e-01
#
#          chrI:34554_A/G  chrI:35128_AG/A  chrI:35466_G/A  chrI:35818_A/G  \
# ...

# %%
pvals_df.to_csv('/storage/cynthiawu/trans_eQTL/Scripts/yeast/yeast_pvals.csv', sep='\t')

# %%
tstat = stats.t.ppf(pvals/2, df=n-2)

# %%
tstat *= -np.sign(corrcoef)

# %%
tstat
# Out:
#          chrI:33040_A/G  chrI:33293_A/T  chrI:34170_T/A  chrI:34308_C/T  \
# YAL062W      -37.091332      -37.128757      -36.957422      -36.507579
# YAL061W       -0.973012       -0.984729       -0.886427       -0.853951
# YAL060W       20.126746       20.540805       20.615424       21.072563
# YAL059W        0.979751        1.126515        1.079580        1.200702
# YAL058W       -1.187806       -1.008388       -1.052063       -1.004822
# ...                 ...             ...             ...             ...
# YPR202W       -0.526312       -0.741120       -0.758386       -0.685467
# YPR203W       -0.255775       -0.428196       -0.443566       -0.543607
# YPR204W       -0.810502       -0.860654       -0.870158       -0.765258
# Q0130         -0.530339       -0.652183       -0.649238       -0.967590
# Q0140          1.001055        1.043476        0.946055        0.956229
#
#          chrI:34554_A/G  chrI:35128_AG/A  chrI:35466_G/A  chrI:35818_A/G  \
# ...

# %%
tstat.to_csv('/storage/cynthiawu/trans_eQTL/Scripts/yeast/yeast_tstat.csv', sep='\t')

# %%
tstat = 2*stats.t.cdf(pvals, df=n-2)

# %%
2*stats.t.cdf(-5.56562090976843, df=449-14)
# Out:
# 4.575545806306689e-08

# %%
2*stats.t.cdf([-5.56562090976843, 3], df=449-14)
# Out:
# array([4.57554581e-08, 1.99714508e+00])

# %%
449-12
# Out:
# 437

# %%
n-2
# Out:
# 1010

# %%
tstat
# Out:
# array([[1.        , 1.        , 1.        , ..., 1.04828194, 1.06297068,
#         1.04253012],
#        [1.25912079, 1.25474628, 1.29270574, ..., 1.10261088, 1.08485436,
#         1.12081494],
#        [1.        , 1.        , 1.        , ..., 1.0529441 , 1.04283823,
#         1.02857202],
#        ...,
#        [1.32384896, 1.30310994, 1.29925237, ..., 1.        , 1.        ,
#         1.        ],
#        [1.44868689, 1.39293691, 1.39426446, ..., 1.0569781 , 1.05045822,
#         1.06709492],
#        [1.24872127, 1.23345517, 1.26934289, ..., 1.38397683, 1.35111288,
#         1.4068078 ]])

# %%
zscores = stats.norm.ppf(pvals/2)

# %%
zscores
# Out:
# array([[-29.45846914, -29.47840585, -29.38699913, ...,  -1.87666183,
#          -1.75637835,  -1.93214096],
#        [ -0.97254381,  -0.98424931,  -0.88603526, ...,  -1.51808613,
#          -1.61377098,  -1.43235978],
#        [-18.45124586, -18.77206437, -18.82958347, ...,  -1.83557275,
#          -1.9290157 ,  -2.09889393],
#        ...,
#        [ -0.81016984,  -0.86028304,  -0.86978   , ..., -19.79869515,
#         -20.53447271, -20.62944072],
#        [ -0.53017084,  -0.65195344,  -0.64900978, ...,  -1.80235202,
#          -1.85709291,  -1.72675678],
#        [ -1.00055901,  -1.04293718,  -0.94561128, ...,  -0.67189609,
#          -0.74636847,  -0.62132492]])

# %%
2*stats.t.cdf(-5.91291853812284, df=437-2)
# Out:
# 6.80344543825369e-09

# %%
2*stats.t.cdf(-5, df=437-2)
# Out:
# 8.329062442900355e-07

# %%
2*stats.norm.cdf(-5)
# Out:
# 5.733031437583866e-07

# %%
# ?stats.norm.cdf

# %%
tstat = stats.t.ppf(pvals/2, df=n-2)

# %%
# ?pd.read_csv

# %%
chr7_zscore = pd.read_csv('/storage/cynthiawu/trans_eQTL/GTex.v8/Run2_031621/Nerve_Tibial/chr7/gene-snp_eqtls_zscore_chr7', sep='\t', index_col='SNP')

# %%
chr7_zscore
# Out:
#                 ENSG00000000003.14  ENSG00000000005.5  ENSG00000000419.12  \
# SNP
# chr7_100057066           -1.194905          -0.989951            0.085893
# chr7_100095455           -0.756337          -0.871391            0.549277
# chr7_100099174            1.041422          -1.782296           -0.771204
# chr7_100105324           -0.010865           3.659655            0.605950
# chr7_100149507           -0.101808          -2.561385           -0.633569
# ...                            ...                ...                 ...
# chr7_99876804             0.788961           1.504527           -1.096855
# chr7_99892567            -0.947238          -0.868502            0.004272
# chr7_99903276             0.802177           0.687440           -1.940201
# chr7_99903288             0.419137           0.650516           -1.089383
# chr7_99971771            -1.713961           0.379525            0.321343
#
# ...

# %%
chr7_pvalues = 2*stats.norm.cdf(-np.abs(chr7_zscore))

# %%
chr7_zscore.index
# Out:
# Index(['chr7_100057066', 'chr7_100095455', 'chr7_100099174', 'chr7_100105324',
#        'chr7_100149507', 'chr7_100159989', 'chr7_100160513', 'chr7_100171334',
#        'chr7_100202222', 'chr7_100419831',
#        ...
#        'chr7_99052428', 'chr7_99185127', 'chr7_99195212', 'chr7_99434970',
#        'chr7_99861633', 'chr7_99876804', 'chr7_99892567', 'chr7_99903276',
#        'chr7_99903288', 'chr7_99971771'],
#       dtype='object', name='SNP', length=1122)

# %%
chr7_pvalues_df = pd.DataFrame(chr7_pvalues, index=chr7_zscore.index, columns=chr7_zscore.columns)

# %%
chr7_pvalues_df
# Out:
#                 ENSG00000000003.14  ENSG00000000005.5  ENSG00000000419.12  \
# SNP
# chr7_100057066            0.232124           0.322198            0.931551
# chr7_100095455            0.449447           0.383541            0.582815
# chr7_100099174            0.297680           0.074701            0.440586
# chr7_100105324            0.991331           0.000253            0.544548
# chr7_100149507            0.918909           0.010426            0.526362
# ...                            ...                ...                 ...
# chr7_99876804             0.430135           0.132446            0.272705
# chr7_99892567             0.343518           0.385120            0.996591
# chr7_99903276             0.422451           0.491805            0.052355
# chr7_99903288             0.675116           0.515359            0.275985
# chr7_99971771             0.086536           0.704298            0.747950
#
# ...

# %%
chr7_pvalue_t = pd.read_csv('/storage/cynthiawu/trans_eQTL/GTex.v8/Run2_031621/Nerve_Tibial/chr7/gene-snp_eqtls_pvalue_chr7', sep='\t', index_col='SNP')

# %%
chr7_pvalue_t
# Out:
#                 ENSG00000000003.14  ENSG00000000005.5  ENSG00000000419.12  \
# SNP
# chr7_100057066            0.232775           0.322748            0.931591
# chr7_100095455            0.449856           0.384021            0.583097
# chr7_100099174            0.298258           0.075398            0.441005
# chr7_100105324            0.991336           0.000284            0.544864
# chr7_100149507            0.918956           0.010762            0.526695
# ...                            ...                ...                 ...
# chr7_99876804             0.430564           0.133172            0.273312
# chr7_99892567             0.344044           0.385599            0.996593
# chr7_99903276             0.422889           0.492172            0.053001
# chr7_99903288             0.675323           0.515702            0.276588
# chr7_99971771             0.087248           0.704483            0.748104
#
# ...

# %%
2*stats.norm.cdf(-np.abs(-5.91291853812284 ))
# Out:
# 3.3609842707032676e-09
